# %%
import sys
from pathlib import Path

print(sys.executable)

PROJECT_ROOT = Path.cwd()
print(PROJECT_ROOT)
# Out:
# c:\Users\ksbong\Documents\GitHub\dmfc-pong-reconstruction\.venv\Scripts\python.exe
# c:\Users\ksbong\Documents\GitHub\dmfc-pong-reconstruction\notebooks

# %%
DATA_DIR = Path("data")
print(DATA_DIR.exists())
print(list(DATA_DIR.glob("*")))
# Out:
# True
# [WindowsPath('data/README.md')]
